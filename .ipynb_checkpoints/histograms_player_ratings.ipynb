# %%
import pandas as pd

# %%
ability_ids = pd.read_csv('ability_ids.csv')

# %%
ability_upgrades = pd.read_csv('ability_upgrades.csv')
ability_upgrades.describe
# Out:
# <bound method NDFrame.describe of          ability  level  time  player_slot  match_id
# 0           5448      1   326            0         0
# 1           5450      2   452            0         0
# 2           5450      3   582            0         0
# 3           5448      4   804            0         0
# 4           5450      5   916            0         0
# 5           5452      6  1077            0         0
# 6           5450      7  1222            0         0
# 7           5448      8  1380            0         0
# 8           5448      9  1554            0         0
# 9           5451     10  1694            0         0
# 10          5452     11  1925            0         0
# 11          5451     12  2194            0         0
# 12          5451     13  2209            0         0
# 13          5451     14  2412            0         0
# 14          5002     15  2609            0         0
# 15          5452     16  2695            0         0
# ...

# %%
item_ids = pd.read_csv('item_ids.csv')
match = pd.read_csv('match.csv')
match_outcome = pd.read_csv('match_outcome.csv')
objectives = pd.read_csv('objectives.csv')
patch_dates = pd.read_csv('patch_dates.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-9713ef0c3072> in <module>()
#       1 item_ids = pd.read_csv('item_ids.csv')
#       2 match = pd.read_csv('match.csv')
# ----> 3 match_outcome = pd.read_csv('match_outcome.csv')
#       4 objectives = pd.read_csv('objectives.csv')
#       5 patch_dates = pd.read_csv('patch_dates.csv')
#
# ...

# %%
item_ids = pd.read_csv('item_ids.csv')
match = pd.read_csv('match.csv')
match_outcome = pd.read_csv('match_outcome')
objectives = pd.read_csv('objectives.csv')
patch_dates = pd.read_csv('patch_dates.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-8c6a298894be> in <module>()
#       1 item_ids = pd.read_csv('item_ids.csv')
#       2 match = pd.read_csv('match.csv')
# ----> 3 match_outcome = pd.read_csv('match_outcome')
#       4 objectives = pd.read_csv('objectives.csv')
#       5 patch_dates = pd.read_csv('patch_dates.csv')
#
# ...

# %%
item_ids = pd.read_csv('item_ids.csv')
match = pd.read_csv('match.csv')
match_outcome = pd.read_csv('match_outcomes.csv')
objectives = pd.read_csv('objectives.csv')
patch_dates = pd.read_csv('patch_dates.csv')

# %%
ability_upgrades.describe
# Out:
# <bound method NDFrame.describe of      ability_id                           ability_name
# 0             0                           ability_base
# 1          5001                         default_attack
# 2          5002                        attribute_bonus
# 3          5003                    antimage_mana_break
# 4          5004                         antimage_blink
# 5          5005                  antimage_spell_shield
# 6          5006                     antimage_mana_void
# 7          5007                    axe_berserkers_call
# 8          5008                      axe_battle_hunger
# 9          5009                      axe_counter_helix
# 10         5010                      axe_culling_blade
# 11         5011                         bane_brain_sap
# 12         5012                          bane_enfeeble
# 13         5013                       bane_fiends_grip
# 14         5014                         bane_nightmare
# ...

# %%
ability_upgrades.describe
# Out:
# <bound method NDFrame.describe of          ability  level  time  player_slot  match_id
# 0           5448      1   326            0         0
# 1           5450      2   452            0         0
# 2           5450      3   582            0         0
# 3           5448      4   804            0         0
# 4           5450      5   916            0         0
# 5           5452      6  1077            0         0
# 6           5450      7  1222            0         0
# 7           5448      8  1380            0         0
# 8           5448      9  1554            0         0
# 9           5451     10  1694            0         0
# 10          5452     11  1925            0         0
# 11          5451     12  2194            0         0
# 12          5451     13  2209            0         0
# 13          5451     14  2412            0         0
# 14          5002     15  2609            0         0
# 15          5452     16  2695            0         0
# ...

# %%
ability_upgrades.describe
# Out:
# <bound method NDFrame.describe of          ability  level  time  player_slot  match_id
# 0           5448      1   326            0         0
# 1           5450      2   452            0         0
# 2           5450      3   582            0         0
# 3           5448      4   804            0         0
# 4           5450      5   916            0         0
# 5           5452      6  1077            0         0
# 6           5450      7  1222            0         0
# 7           5448      8  1380            0         0
# 8           5448      9  1554            0         0
# 9           5451     10  1694            0         0
# 10          5452     11  1925            0         0
# 11          5451     12  2194            0         0
# 12          5451     13  2209            0         0
# 13          5451     14  2412            0         0
# 14          5002     15  2609            0         0
# 15          5452     16  2695            0         0
# ...

# %%
chat.describe()
# Out:
#            match_id          slot          time
# count  1.439488e+06  1.439488e+06  1.439488e+06
# mean   2.495673e+04  4.493948e+00  1.708153e+03
# std    1.457124e+04  2.877044e+00  9.868280e+02
# min    0.000000e+00 -9.000000e+00 -9.070000e+02
# 25%    1.227900e+04  2.000000e+00  1.020000e+03
# 50%    2.483900e+04  5.000000e+00  1.776000e+03
# 75%    3.767800e+04  7.000000e+00  2.386000e+03
# max    4.999900e+04  9.000000e+00  1.605700e+04

# %%
cluster_regions.describe()
# Out:
#           cluster
# count   53.000000
# mean   174.867925
# std     40.967641
# min    111.000000
# 25%    137.000000
# 50%    181.000000
# 75%    204.000000
# max    261.000000

# %%
hero_names.describe
# Out:
# <bound method NDFrame.describe of                                   name  hero_id       localized_name
# 0               npc_dota_hero_antimage        1            Anti-Mage
# 1                    npc_dota_hero_axe        2                  Axe
# 2                   npc_dota_hero_bane        3                 Bane
# 3            npc_dota_hero_bloodseeker        4          Bloodseeker
# 4         npc_dota_hero_crystal_maiden        5       Crystal Maiden
# 5            npc_dota_hero_drow_ranger        6          Drow Ranger
# 6            npc_dota_hero_earthshaker        7          Earthshaker
# 7             npc_dota_hero_juggernaut        8           Juggernaut
# 8                 npc_dota_hero_mirana        9               Mirana
# 9              npc_dota_hero_morphling       10            Morphling
# 10             npc_dota_hero_nevermore       11         Shadow Fiend
# 11        npc_dota_hero_phantom_lancer       12       Phantom Lancer
# ...

# %%
item_ids.describe
# Out:
# <bound method NDFrame.describe of      item_id               item_name
# 0          1                   blink
# 1          2        blades_of_attack
# 2          3              broadsword
# 3          4               chainmail
# 4          5                claymore
# 5          6       helm_of_iron_will
# 6          7                 javelin
# 7          8          mithril_hammer
# 8          9               platemail
# 9         10            quarterstaff
# 10        11          quelling_blade
# 11        12      ring_of_protection
# 12        13               gauntlets
# 13        14                slippers
# 14        15                  mantle
# 15        16                branches
# 16        17        belt_of_strength
# 17        18          boots_of_elves
# 18        19                    robe
# 19        20                 circlet
# 20        21                ogre_axe
# 21        22       blade_of_alacrity
# 22        23       staff_of_wizardry
# ...

# %%
match.describe
# Out:
# <bound method NDFrame.describe of        match_id  start_time  duration  tower_status_radiant  \
# 0             0  1446750112      2375                  1982
# 1             1  1446753078      2582                     0
# 2             2  1446764586      2716                   256
# 3             3  1446765723      3085                     4
# 4             4  1446796385      1887                  2047
# 5             5  1446798766      1574                  2047
# 6             6  1446800938      2124                  1972
# 7             7  1446804030      2328                  2046
# 8             8  1446819063      2002                     0
# 9             9  1446837251      2961                     0
# 10           10  1446839926      1562                  1983
# 11           11  1446850598      3280                     0
# 12           12  1446853394      3995                     0
# 13           13  1446855028      2452                  1956
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#histogram of total wins
player_ratings_totalwins = player_ratings[player_ratings.position.isin(['total_wins'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-13265b7b1102> in <module>()
#       1 #histogram of total wins
# ----> 2 player_ratings_totalwins = player_ratings[player_ratings.position.isin(['total_wins'])]
#
# NameError: name 'player_ratings' is not defined

# %%
player_ratings = pd.read_csv('player_ratings.csv')
player_ratings_totalwins = player_ratings[player_ratings.position.isin(['total_wins'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-eaec9ce48856> in <module>()
#       1 player_ratings = pd.read_csv('player_ratings.csv')
# ----> 2 player_ratings_totalwins = player_ratings[player_ratings.position.isin(['total_wins'])]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'position'

# %%
plt.figure(1)
plt.hist(player_ratings["total_wins"])
plt.xlabel("total_wins")
plt.savefig('total_wins_hist')

# %%
player_ratings.describe()
# Out:
#          account_id    total_wins  total_matches   trueskill_mu  \
# count  8.342260e+05  8.342260e+05   8.342260e+05  834226.000000
# mean  -9.225868e+07  5.479852e+00   1.095979e+01      25.112577
# std    8.103222e+07  1.760984e+03   3.629559e+03       3.231603
# min   -2.991940e+08  0.000000e+00   1.000000e+00       4.993478
# 25%   -1.499249e+08  0.000000e+00   1.000000e+00      22.906655
# 50%   -9.585022e+07  1.000000e+00   2.000000e+00      25.018193
# 75%    4.883475e+04  3.000000e+00   6.000000e+00      27.240350
# max    3.305130e+05  1.608398e+06   3.315071e+06      48.825892
#
#        trueskill_sigma
# count    834226.000000
# mean          7.270275
# std           1.128826
# min           1.404098
# 25%           6.957458
# 50%           7.732504
# 75%           8.058739
# max           8.333689

# %% [markdown]
# Histogram scale is wonky for total wins, because there is an outlier piece of data that shows that a user has once over 1.6 million matches

# %%
from pandas import DataFrame
player_ratings_df = DataFrame(player_ratings)

# %%
test = player_ratings_df.sort_values('total_wins', ascending=False)

# %%
test.drop(test.index[[0]])
# Out:
#         account_id  total_wins  total_matches  trueskill_mu  trueskill_sigma
# 443072        6647         396            785     25.383555         1.463347
# 549840       12357         341            623     27.023187         1.511440
# 525335       77866         302            570     26.434280         1.683808
# 93220        35770         290            561     27.056765         1.588747
# 359807        8101         274            510     28.548270         1.556991
# 10433        17194         271            495     29.066962         1.479347
# 57399        55446         269            491     26.235939         1.745890
# 72501        28485         262            526     26.190546         1.579630
# 28619        24722         255            462     30.554834         1.443408
# 566759        2765         251            455     28.514874         1.633503
# 239296      138306         247            458     27.120535         1.610378
# ...

# %% [markdown]
# Ordered the playing ratings data by the total matches played and found the outlier. Deleted the outlier. Will now ouput the histogram

# %%
test
# Out:
#         account_id  total_wins  total_matches  trueskill_mu  trueskill_sigma
# 834225           0     1608398        3315071     25.000000         8.333333
# 443072        6647         396            785     25.383555         1.463347
# 549840       12357         341            623     27.023187         1.511440
# 525335       77866         302            570     26.434280         1.683808
# 93220        35770         290            561     27.056765         1.588747
# 359807        8101         274            510     28.548270         1.556991
# 10433        17194         271            495     29.066962         1.479347
# 57399        55446         269            491     26.235939         1.745890
# 72501        28485         262            526     26.190546         1.579630
# 28619        24722         255            462     30.554834         1.443408
# 566759        2765         251            455     28.514874         1.633503
# ...

# %%
test = test.drop(test.index[[0]])

# %%
# Out:
#         account_id  total_wins  total_matches  trueskill_mu  trueskill_sigma
# 443072        6647         396            785     25.383555         1.463347
# 549840       12357         341            623     27.023187         1.511440
# 525335       77866         302            570     26.434280         1.683808
# 93220        35770         290            561     27.056765         1.588747
# 359807        8101         274            510     28.548270         1.556991
# 10433        17194         271            495     29.066962         1.479347
# 57399        55446         269            491     26.235939         1.745890
# 72501        28485         262            526     26.190546         1.579630
# 28619        24722         255            462     30.554834         1.443408
# 566759        2765         251            455     28.514874         1.633503
# 239296      138306         247            458     27.120535         1.610378
# ...

# %%
#Histogram of total wins from 1-25 wins
plt.figure(1)
plt.hist(test["total_wins"],[i for i in range(1, 25)])
plt.xlabel("total_wins 1-25")
plt.savefig('total_wins_hist_low')

# %%
#Histogram of total wins from 25-400 wins
plt.figure(1)
plt.hist(test["total_wins"],[25*i for i in range(1,17)])
plt.xlabel("total_wins 25-400")
plt.savefig('total_wins_hist_rest')

# %%
#Histogram of total wins from 1-25 wins
plt.figure(1)
plt.hist(test["total_matches"],[i for i in range(1, 25)])
plt.xlabel("total_ 1-25")
plt.savefig('total_matches_hist_low')

#Histogram of total wins from 25-400 wins
plt.figure(2)
plt.hist(player_ratings_df["total_matches"],[25*i for i in range(1,17)])
plt.xlabel("total_matches 25-400")
plt.savefig('total_matches_hist_rest')

# %%
#Histogram of trueskill_mu
plt.figure(1)
plt.hist(player_ratings_df["trueskill_mu"])
plt.xlabel("trueskill_mu")
plt.savefig('total_matches_trueskill_mu')

# %%
#Histogram of trueskill_sigma
plt.figure(1)
plt.hist(player_ratings_df["trueskill_sigma"])
plt.xlabel("trueskill_sigma")
plt.savefig('total_matches_trueskill_sigma')
